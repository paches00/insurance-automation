# %%
import os
import pandas as pd
import numpy as np

# %%
# Read in the data
path = r'C:\Users\juan\My Drive\AAUniversidad\AAsignaturas\Third Year\BCSAI_22_23_THIRD__Q2\AI STATISTICAL LEARNING & PREDICTION\Group_project/all_pairs'

# Create a list of all csv files in the folder
files = [f for f in os.listdir(path) if f.endswith('.csv')]

# Add to each csv a column with the name of the file
for f in files:
    df = pd.read_csv(os.path.join(path, f))
    df['file'] = f
    df.to_csv(os.path.join(path, f), index=False)

# # concatenate all csv files into one dataframe
df = pd.concat([pd.read_csv(os.path.join(path, f)) for f in files], ignore_index=True)
df
# Out:
#         Unnamed: 0.1  Unnamed: 0                          campo    x     y  \
# 0                  0           0                          fecha   42   106
# 1                  1           1                           hora  224   105
# 2                  2           2              localizacion pais  352   104
# 3                  3           3    danos_materiales objetos si  378   186
# 4                  4           4  danos_materiales vehículos no   89   189
# ...              ...         ...                            ...  ...   ...
# 683377           302         302                  texto maquina  707   934
# 683378           303         303                  texto maquina  467   980
# 683379           304         304                  texto maquina  495   985
# 683380           305         305                  texto maquina  538  1000
# 683381           306         306                  texto maquina  710   978
#
#           w   h      text                       file
# 0       156  21  2/7/2012  parte_amistoso_0_23_3.csv
# 1        83  22     17:38  parte_amistoso_0_23_3.csv
# 2        64  14    Espana  parte_amistoso_0_23_3.csv
# 3        14  15         X  parte_amistoso_0_23_3.csv
# 4        16  13         X  parte_amistoso_0_23_3.csv
# ...     ...  ..       ...                        ...
# 683377   24  19       NaN   parte_amistoso_9_9_9.csv
# 683378   22  17       NaN   parte_amistoso_9_9_9.csv
# 683379  210  15       NaN   parte_amistoso_9_9_9.csv
# 683380  123  19       NaN   parte_amistoso_9_9_9.csv
# 683381   22  20       NaN   parte_amistoso_9_9_9.csv
#
# [683382 rows x 9 columns]

# %%
# Read in the first csv file
# df = pd.read_csv(os.path.join(path, files[0]))
df = df.dropna()

# Transform the unique values in the column 'campo' into columns and add the values of the column 'text' to the row, and merge all the rows with the same 'campo' value
df_ = df.pivot(index='file', columns='campo', values='text').reset_index()
df_
# Out:
# campo                       file      A  aseguradora agencia  \
# 0      parte_amistoso_0_23_3.csv        Canet d'en berenguer
# 1      parte_amistoso_1_19_3.csv                     Villava
# 2      parte_amistoso_1_20_3.csv                     Villava
# 3      parte_amistoso_1_23_3.csv                     Villava
# 4      parte_amistoso_1_26_3.csv                     Villava
# ...                          ...                         ...
# 2221   parte_amistoso_9_9_21.csv                  RETORTILLO
# 2222    parte_amistoso_9_9_3.csv                 LA JONQUERA
# 2223    parte_amistoso_9_9_6.csv  Castillejo de martin viejo
# 2224    parte_amistoso_9_9_7.csv                        Goni
# 2225    parte_amistoso_9_9_9.csv                       GARES
#
# campo A  aseguradora agencia direccion A  aseguradora agencia nombre  \
# 0                      C/ aguilera 100                         Irene
# 1                      Calle Serrano 9                  Maria Isabel
# 2                      Calle Serrano 9                  Maria Isabel
# 3                      Calle Serrano 9                  Maria Isabel
# 4                      Calle Serrano 9                  Maria Isabel
# ...                                ...                           ...
# 2221                      C/ CRESPO 43                  JOSE ANTONIO
# 2222                    C/ GALLARDO 63                      CONSUELO
# 2223                   Calle alonso 82                         Nerea
# 2224                  Calle manzano 90                   Maria jesus
# 2225                       C/ CALVO 96                MARIA VICTORIA
#
# campo A  aseguradora carta_verde A  aseguradora carta_verde_desde  \
# 0                          75114                             1/17
# 1                          95916                              6/5
# 2                          95916                              6/5
# 3                          95916                              6/5
# 4                          95916                              6/5
# ...                          ...                              ...
# 2221                        8544                             10/3
# 2222                       43413                              9/1
# 2223                       66182                             5/18
# 2224                       85345                             7/20
# 2225                       78293                             7/25
#
# campo A  aseguradora carta_verde_hasta A  aseguradora danos_propios_no  \
# 0                                 5/12                               X
# 1                                 2/30                               X
# 2                                 2/30                               X
# 3                                 2/30                               X
# 4                                 2/30                               X
# ...                                ...                             ...
# 2221                              5/16                               X
# 2222                              6/22                               X
# 2223                              1/14
# 2224                              5/19
# 2225                              6/23
#
# campo A  aseguradora danos_propios_si A  aseguradora num_poliza  ...  \
# 0                                   X                      2271  ...
# 1                                   X                      7746  ...
# 2                                   X                      7746  ...
# 3                                   X                      7746  ...
# 4                                   X                      7746  ...
# ...                               ...                       ...  ...
# 2221                                                       4232  ...
# 2222                                X                       308  ...
# 2223                                                       1814  ...
# 2224                                                       3747  ...
# 2225                                                       8730  ...
#
# campo danos_materiales objetos si danos_materiales vehiculos si  \
# 0                               X                             X
# 1
# 2
# 3
# 4
# ...                           ...                           ...
# 2221                                                          X
# 2222                            X
# 2223
# 2224                                                          X
# 2225
#
# campo danos_materiales vehículos no       fecha   hora localizacion pais  \
# 0                                 X    2/7/2012  17:38            Espana
# 1                                 X   14/1/1980  06:56        Inglaterra
# 2                                 X   14/1/1980  06:56        Inglaterra
# 3                                 X   14/1/1980  06:56        Inglaterra
# 4                                 X   14/1/1980  06:56        Inglaterra
# ...                             ...         ...    ...               ...
# 2221                                  23/8/2022  06:14            ESPANA
# 2222                              X   5/10/1989  02:20            ESPANA
# 2223                                 17/11/2013  23:05            Espana
# 2224                                   2/8/2014  09:51            Espana
# 2225                              X    4/1/2018  04:53           UCRANIA
#
# campo                        lugar                        testigos  \
# 0      San vicente de la sonsierra  Veronica dominguez, 6592871886
# 1                       Gallocanta       Juana Esteban, 6551789482
# 2                       Gallocanta       Juana Esteban, 6551789482
# 3                       Gallocanta       Juana Esteban, 6551789482
# 4                       Gallocanta       Juana Esteban, 6551789482
# ...                            ...                             ...
# 2221          HIGUERA DE CALATRAVA       SERGIO TORRES, 6186486572
# 2222                 FUENTELCESPED      ANTONIA SUAREZ, 6750624968
# 2223                      Leganiel     Dolores jimenez, 6903999764
# 2224                 Pozo de urama      Felipe garrido, 6126860089
# 2225                   TORREBLACOS       ESTHER BELTRAN, 640302766
#
# campo victimas no victimas si
# 0               X
# 1                           X
# 2                           X
# 3                           X
# 4                           X
# ...           ...         ...
# 2221
# 2222            X           X
# 2223                        X
# 2224
# 2225            X           X
#
# [2226 rows x 114 columns]

# %%
# Find the count of duplicated rows
print("The number of duplicated rows is: ", df_.drop(columns=['file']).duplicated().sum(), ". The % of duplicated rows is: ", df_.drop(columns=['file']).duplicated().sum()/len(df_)*100, "%")
# Out:
# The number of duplicated rows is:  2162 . The % of duplicated rows is:  97.12488769092543 %

# %%
# Show all columns 
pd.set_option('display.max_columns', None)

# %%
# Drop the column 'file' and drop duplicates
dff = df_.drop(columns=['file']).drop_duplicates()

# Save the dataframe as a xlsx file
dff.to_excel(r'C:\Users\juan\My Drive\AAUniversidad\AAsignaturas\Third Year\BCSAI_22_23_THIRD__Q2\AI STATISTICAL LEARNING & PREDICTION\Group_project/df.xlsx', index = False)

# %%
# unique values on campo column that have Nan values in the other columns
df[df.isnull().any(axis=1)].campo.unique()
# Out:
# array(['texto maquina'], dtype=object)

# %%
df = pd.read_excel(r'C:\Users\juan\My Drive\AAUniversidad\AAsignaturas\Third Year\BCSAI_22_23_THIRD__Q2\AI STATISTICAL LEARNING & PREDICTION\Group_project/df.xlsx')

# %%
df[:1]
# Out:
#   A  aseguradora agencia A  aseguradora agencia direccion  \
# 0   Canet d'en berenguer                  C/ aguilera 100
#
#   A  aseguradora agencia nombre  A  aseguradora carta_verde  \
# 0                         Irene                       75114
#
#   A  aseguradora carta_verde_desde A  aseguradora carta_verde_hasta  \
# 0                             1/17                             5/12
#
#   A  aseguradora danos_propios_no A  aseguradora danos_propios_si  \
# 0                               X                               X
#
#    A  aseguradora num_poliza A  aseguradora pais A  aseguradora telefono  \
# 0                       2271              Espana              6113336419
#
#   A  aseguradora_nombre A  conductor apellidos A  conductor categoria  \
# 0               Balumba              Contreras                      B
#
#   A  conductor danos_apreciados A  conductor direccion A  conductor fecha_nac  \
# 0              Guantera quemado            C/ conde 66              27/8/1961
#
#   A  conductor nombre A  conductor pais A  conductor permiso  \
# 0            Victoria            Italia            16572018f
#
#     A  conductor telefono A  conductor valido_hasta A  remolque matricula  \
# 0  Conde.lidia@outlook.es                  2/6/2019               6395xao
#
#   A  remolque pais A  vehiculo marca_modelo A  vehiculo matricula  \
# 0           Espana       Mitsubishi compact               8386mgp
#
#   A  vehiculo pais A 1 A 10 A 11 A 12 A 13 A 14 A 15 A 16 A 17 A 2 A 3 A 4  \
# 0           Espana   X    X    X         X    X                  X   X
#
#   A 5 A 6 A 7 A 8 A 9 A asegurado apellidos  A asegurado codigo_postal  \
# 0   X       X       X                Zamora                       4028
#
#   A asegurado direccion A asegurado nombre A asegurado pais  \
# 0        C/ bermudez 97      Maria dolores          Francia
#
#          A asegurado telefono A n_casillas B 1 B 10 B 11 B 12 B 13 B 14 B 15  \
# 0  Plaza.ana maria@hotmail.es            3   X                        X    X
#
#   B 16 B 17 B 2 B 3 B 4 B 5 B 6 B 7 B 8 B 9 B asegurado apellidos  \
# 0    X    X   X   X   X           X                      Carrillo
#
#    B asegurado codigo_postal B asegurado direccion B asegurado nombre  \
# 0                      94112      Calle ramirez 99               Hugo
#
#   B asegurado pais B asegurado telefono B aseguradora agencia  \
# 0           Espana           6540063482         Iglesiarrubia
#
#   B aseguradora agencia direccion B aseguradora agencia nombre  \
# 0           Calle de la fuente 84                        Maria
#
#   B aseguradora agencia pais  B aseguradora carta_verde  \
# 0                     Espana                      19043
#
#   B aseguradora carta_verde_desde B aseguradora carta_verde_hasta  \
# 0                             3/9                            7/22
#
#   B aseguradora danos_propios no B aseguradora danos_propios si  \
# 0                              X
#
#    B aseguradora n_poliza        B aseguradora telefono B aseguradora_nombre  \
# 0                    5406  Izquierdo.antonia@hotmail.es                Caser
#
#   B conductor apellidos B conductor categoria B conductor direccion  \
# 0              Aguilera                     B          C/ guerra 85
#
#   B conductor fecha_nac B conductor nombre B conductor pais  \
# 0             15/9/1997             Carmen           Espana
#
#   B conductor permiso      B conductor telefono B conductor valido_hasta  \
# 0           20437005o  Beltran.gonzalo@gmail.es                 2/2/2027
#
#                           B danos_apreciados B n_casillas  \
# 0  Sistema antibloqueo de ruedas desconchado            3
#
#   B remolque matricula B remolque pais B vehiculo marca_modelo  \
# 0              5558zue          Espana             Toyota f355
#
#   B vehiculo matricula B vehiculo pais danos_materiales objetos no  \
# 0              8933mnm           China                           X
#
#   danos_materiales objetos si danos_materiales vehiculos si  \
# 0                           X                             X
#
#   danos_materiales vehículos no     fecha   hora localizacion pais  \
# 0                             X  2/7/2012  17:38            Espana
#
#                          lugar                        testigos victimas no  \
# 0  San vicente de la sonsierra  Veronica dominguez, 6592871886           X
#
#   victimas si
# 0

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Cargar los datos
data = pd.read_excel(r'C:\Users\juan\My Drive\AAUniversidad\AAsignaturas\Third Year\BCSAI_22_23_THIRD__Q2\AI STATISTICAL LEARNING & PREDICTION\Group_project/df.xlsx')

# Crear una columna para la hora del accidente
data['hora'] = pd.to_datetime(data['hora'])
data['hora'] = data['hora'].apply(lambda x: x.hour)

# Crear el gráfico de barras
plt.figure(figsize=(10,5))
plt.hist(data['hora'], bins=24, edgecolor='black', linewidth=1.2)
plt.xlabel('Hora del accidente')
plt.ylabel('Número de accidentes')
plt.title('Accidentes por hora del día')
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Cargar los datos
data = df.copy()

# Si la columna 'victimas si' tiene x o X en la celda, se cambia por 1
data['victimas si'] = data['victimas si'].apply(lambda x: 1 if x == 'x' or x == 'X' else 0)
data['victimas no'] = data['victimas no'].apply(lambda x: 0 if x == 'x' or x == 'X' else 1)


# Crear el gráfico de barras
sns.countplot(data=data, x='victimas si', palette='viridis')
sns.countplot(data=data, x='victimas no', palette='viridis')

plt.xlabel('Número de víctimas')
plt.ylabel('Número de accidentes')
plt.title('Número de víctimas en accidentes')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Cargar los datos
Age = data.copy()
Age['edad'] = Age["A  conductor fecha_nac"].apply(lambda x: int(x.split('/')[-1]))
# Edad del conductor con fecha de nacimiento
Age["A conductor edad"] = Age["edad"].apply(lambda x: 2023 - x)

# Group by 'A conductor edad' and sum the values of 'victimas si' y dividir por el total de accidentes
Age = Age.groupby('A conductor edad')[['victimas si', 'victimas no']]
# Age = Age.sum()/len(data)

Age.sum()
# Crear el diagrama de dispersión
plt.figure(figsize=(10,5))
plt.plot(Age.sum().index, Age.sum()['victimas si'], 'o', color='red')
plt.xlabel('Edad del conductor')
plt.ylabel('Numbero de Víctimas')
plt.title('Edad del conductor vs. Número de víctimas')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
data = df.copy()

# Si la columna 'victimas si' tiene x o X en la celda, se cambia por 1
data['danos_materiales objetos'] = data['danos_materiales objetos si'].apply(lambda x: 1 if x == 'x' or x == 'X' else 0)
data['danos_materiales vehiculos'] = data['danos_materiales vehiculos si'].apply(lambda x: 1 if x == 'x' or x == 'X' else 0)

# Crear el gráfico de barras
sns.countplot(data=data, x='danos_materiales objetos', palette='viridis')

plt.xlabel('Número de objetos involucrados')
plt.ylabel('Número de accidentes')
plt.title('Número de objetos involucrados en accidentes')
plt.xticks([0, 1], ['0', '1 o más'])
plt.show()
