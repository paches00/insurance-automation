# %%
import pandas as pd

# %%
df = pd.read_csv("checkbox_detected.csv")

# %%
df
# Out:
#                                                 campo    x    y   w   h text
# 0                     Victima(s) incluso leve(s) — No  755  111  10  10    X
# 1                     Victima(s) incluso leve(s) — Si  853  111  10  10  NaN
# 2   Daños materiales: Vehículos distintos de A y B...   93  188  11  10    X
# 3   Daños materiales: Vehículos distintos de A y B...  191  188  10  10    X
# 4   Daños materiales:objetos distintos al vehículo...  282  188  10  11    X
# 5   Daños materiales: objetos distintos al vehícul...  380  188  10  11    X
# 6                         A Estaba estacionado/parado  449  327  17  16    X
# 7                         B Estaba estacionado/parado  733  327  16  16    X
# 8       A Salía de un estacionamiento abriendo puerta  449  349  17  17    X
# 9       B Salía de un estacionamiento abriendo puerta  733  349  16  17    X
# 10                                 A Iba a estacionar  449  392  17  16    X
# ...
